# %% [markdown]
# # List Products & Measurements
# A simple notebook to list products available within DEA and also to investigate the measurements within the products (based on a dea getting started notebook).

# %%
# %matplotlib inline
import datacube
import pandas
pandas.set_option('display.max_colwidth', 200)
pandas.set_option('display.max_rows', None)

# %%
dc = datacube.Datacube()

# %% [markdown]
# ## List Products
# We can get all the products in datacube as a `pandas DataFrame`:

# %%
products = dc.list_products()

# %%
products.columns.tolist()
# Out:
# ['name',
#  'description',
#  'gqa_abs_iterative_mean_xy',
#  'orbit',
#  'format',
#  'region_code',
#  'gqa_error_message',
#  'ancillary_quality',
#  'time',
#  'label',
#  'instrument',
#  'gqa_ref_source',
#  'gqa_iterative_stddev_xy',
#  'gqa_stddev_xy',
#  'gqa_final_gcp_count',
#  'gqa_mean_xy',
#  'platform',
#  'gqa_cep90',
#  'gqa',
#  'gqa_iterative_mean_xy',
#  'lat',
#  'lon',
#  'gsi',
#  'creation_time',
#  'sat_row',
#  'sat_path',
#  'product_type',
#  'gqa_abs_xy',
#  'crs',
#  'resolution',
#  'tile_size',
#  'spatial_dimensions']

# %% [markdown]
# We don't want to see most of these columns, so we will limit the `DataFrame` to just a few, and show the rows with a `product_type` of `nbar`:

# %%
display_columns = ['name', 'description', 'platform', 'instrument', 'crs', 'resolution']
dea_products = products[display_columns].dropna()
nbar_products = products[products['product_type'] == 'nbar'][display_columns].dropna()
dea_products
# Out:
#                              name  \
# id
# 36             bom_rainfall_grids
# 32                       dsm1sv10
# 99    fc_percentile_albers_annual
# 53                      gamma_ray
# 69                  ls5_fc_albers
# 6                 ls5_nbar_albers
# 26               ls5_nbart_albers
# 83     ls5_nbart_geomedian_annual
# 104         ls5_nbart_tmad_annual
# 23                  ls5_pq_albers
# 70                  ls7_fc_albers
# 21                ls7_nbar_albers
# 29               ls7_nbart_albers
# 82     ls7_nbart_geomedian_annual
# 103         ls7_nbart_tmad_annual
# 22                  ls7_pq_albers
# 98        ls8_barest_earth_mosaic
# 71                  ls8_fc_albers
# 19                ls8_nbar_albers
# 60            ls8_nbar_oli_albers
# 28               ls8_nbart_albers
# 81     ls8_nbart_geomedian_annual
# 61           ls8_nbart_oli_albers
# 102         ls8_nbart_tmad_annual
# 20                  ls8_pq_albers
# 80              ls8_pq_oli_albers
# 105  mangrove_extent_cover_albers
# 56                 srtm_dem1sv1_0
# 97            wofs_annual_summary
# 100          wofs_apr_oct_summary
# 85          wofs_filtered_summary
# 101          wofs_nov_mar_summary
# 84                   wofs_summary
#
#                                                                                                                         description  \
# id
# 36                                                                Interpolated Rain Gauge Precipitation 1-Day Australia 5km Gridded
# 32                                                                                                             DSM 1sec Version 1.0
# 99                    Landsat Fractional Cover percentile 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 53                                                                              The 2015 radiometric or gamma-ray grid of Australia
# 69                             Landsat 5 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 6                      Landsat 5 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 26                    Landsat 5 Surface Reflectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 83                   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 104  Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 23                                Landsat 5 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 70                             Landsat 7 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 21                     Landsat 7 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 29                    Landsat 7 Surface Reflectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 82                   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 103  Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 22                                Landsat 7 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 98           Landsat-8 Barest Earth pixel composite mosaic 25 metre, 25km tile, Australian Albers Equal Area projection (EPSG:3577)
# 71                             Landsat 8 Fractional Cover 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 19                     Landsat 8 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 60                     Landsat 8 Surface Reflectance NBAR 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 28                    Landsat 8 Surface Relfectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 81                   Surface Reflectance Geometric Median 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 61                    Landsat 8 Surface Relfectance NBART 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 102  Surface Reflectance Triple Median Absolute Deviation 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 20                                Landsat 8 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 80                                Landsat 8 Pixel Quality 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 105                   Mangroves conver extent and classes 25 metre, 100km tile, Australian Albers Equal Area projection (EPSG:3577)
# 56                                                                                                             DEM 1sec Version 1.0
# 97                                                                                  Water Observations from Space Annual Statistics
# 100                                                                       Water Observations from Space April to October Statistics
# 85                                                                     Water Observations from Space Statistics confidence filtered
# 101                                                                      Water Observations from Space November to March Statistics
# 84                                                                                         Water Observations from Space Statistics
#
#                           platform              instrument  \
# id
# 36                             BoM              rain gauge
# 32                            SRTM                     SIR
# 99   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 53                        aircraft  gamma_ray spectrometer
# 69                       LANDSAT_5                      TM
# 6                        LANDSAT_5                      TM
# 26                       LANDSAT_5                      TM
# 83                       LANDSAT_5                      TM
# 104                      LANDSAT_5                      TM
# 23                       LANDSAT_5                      TM
# 70                       LANDSAT_7                     ETM
# 21                       LANDSAT_7                     ETM
# 29                       LANDSAT_7                     ETM
# 82                       LANDSAT_7                     ETM
# 103                      LANDSAT_7                    ETM+
# 22                       LANDSAT_7                     ETM
# 98                       LANDSAT_8                     OLI
# 71                       LANDSAT_8                OLI_TIRS
# 19                       LANDSAT_8                OLI_TIRS
# 60                       LANDSAT_8                     OLI
# 28                       LANDSAT_8                OLI_TIRS
# 81                       LANDSAT_8                     OLI
# 61                       LANDSAT_8                     OLI
# 102                      LANDSAT_8                     OLI
# 20                       LANDSAT_8                OLI_TIRS
# 80                       LANDSAT_8                     OLI
# 105  LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 56         Space Shuttle Endeavour                     SIR
# 97   LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 100  LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 85   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
# 101  LANDSAT_5,LANDSAT_7,LANDSAT_8              TM,ETM,OLI
# 84   LANDSAT_5,LANDSAT_7,LANDSAT_8             TM,ETM+,OLI
#
#                                                                                                                                                         crs  \
# id
# 36                                                                                                                                                EPSG:4326
# 32                                                                                                                                                EPSG:4326
# 99                                                                                                                                                EPSG:3577
# 53   GEOGCS["GEOCENTRIC DATUM of AUSTRALIA",DATUM["GDA94",SPHEROID["GRS80",6378137,298.257222101]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433]]
# 69                                                                                                                                                EPSG:3577
# 6                                                                                                                                                 EPSG:3577
# 26                                                                                                                                                EPSG:3577
# 83                                                                                                                                                EPSG:3577
# 104                                                                                                                                               EPSG:3577
# 23                                                                                                                                                EPSG:3577
# 70                                                                                                                                                EPSG:3577
# 21                                                                                                                                                EPSG:3577
# 29                                                                                                                                                EPSG:3577
# 82                                                                                                                                                EPSG:3577
# 103                                                                                                                                               EPSG:3577
# 22                                                                                                                                                EPSG:3577
# 98                                                                                                                                                EPSG:3577
# 71                                                                                                                                                EPSG:3577
# 19                                                                                                                                                EPSG:3577
# 60                                                                                                                                                EPSG:3577
# 28                                                                                                                                                EPSG:3577
# 81                                                                                                                                                EPSG:3577
# 61                                                                                                                                                EPSG:3577
# 102                                                                                                                                               EPSG:3577
# 20                                                                                                                                                EPSG:3577
# 80                                                                                                                                                EPSG:3577
# 105                                                                                                                                               EPSG:3577
# 56                                                                                                                                                EPSG:4326
# 97                                                                                                                                                EPSG:3577
# 100                                                                                                                                               EPSG:3577
# 85                                                                                                                                                EPSG:3577
# 101                                                                                                                                               EPSG:3577
# 84                                                                                                                                                EPSG:3577
#
#                                 resolution
# id
# 36                           (-0.05, 0.05)
# 32   (-0.00027777777778, 0.00027777777778)
# 99                               (-25, 25)
# 53                         (-0.001, 0.001)
# 69                               (-25, 25)
# 6                                (-25, 25)
# 26                               (-25, 25)
# 83                               (-25, 25)
# 104                              (-25, 25)
# 23                               (-25, 25)
# 70                               (-25, 25)
# 21                               (-25, 25)
# 29                               (-25, 25)
# 82                               (-25, 25)
# 103                              (-25, 25)
# 22                               (-25, 25)
# 98                               (-25, 25)
# 71                               (-25, 25)
# 19                               (-25, 25)
# 60                               (-25, 25)
# 28                               (-25, 25)
# 81                               (-25, 25)
# 61                               (-25, 25)
# 102                              (-25, 25)
# 20                               (-25, 25)
# 80                               (-25, 25)
# 105                              (-25, 25)
# 56   (-0.00027777777778, 0.00027777777778)
# 97                               (-25, 25)
# 100                              (-25, 25)
# 85                               (-25, 25)
# 101                              (-25, 25)
# 84                               (-25, 25)

# %% [markdown]
# ## List Measurements

# %%
measurements = dc.list_measurements()

# %%
measurements.columns.tolist()
# Out:
# ['name',
#  'dtype',
#  'units',
#  'nodata',
#  'aliases',
#  'spectral_definition',
#  'flags_definition',
#  'number']

# %%
display_columns = ['units', 'nodata', 'aliases']

# %% [markdown]
# We can look at the measurements for just one product, such as `ls5_nbar_albers`:

# %%
measurements[display_columns].loc['fc_percentile_albers_annual']
# Out:
#                units nodata aliases
# measurement
# BS_PC_10     percent     -1     NaN
# PV_PC_10     percent     -1     NaN
# NPV_PC_10    percent     -1     NaN
# BS_PC_50     percent     -1     NaN
# PV_PC_50     percent     -1     NaN
# NPV_PC_50    percent     -1     NaN
# BS_PC_90     percent     -1     NaN
# PV_PC_90     percent     -1     NaN
# NPV_PC_90    percent     -1     NaN

# %% [markdown]
# Or we can look at a list of them:

# %%
product_list = nbar_products.name.tolist()
product_list
# Out:
# ['ls5_nbar_albers',
#  'ls7_nbar_albers',
#  'ls8_nbar_albers',
#  'ls8_nbar_oli_albers']

# %%
measurements[display_columns].loc[product_list]
# Out:
#                                     units nodata                    aliases
# product             measurement
# ls5_nbar_albers     blue                1   -999             [band_1, blue]
#                     green               1   -999            [band_2, green]
#                     red                 1   -999              [band_3, red]
#                     nir                 1   -999              [band_4, nir]
#                     swir1               1   -999            [band_5, swir1]
#                     swir2               1   -999            [band_7, swir2]
# ls7_nbar_albers     blue                1   -999             [band_1, blue]
#                     green               1   -999            [band_2, green]
#                     red                 1   -999              [band_3, red]
#                     nir                 1   -999              [band_4, nir]
#                     swir1               1   -999            [band_5, swir1]
#                     swir2               1   -999            [band_7, swir2]
# ls8_nbar_albers     coastal_aerosol     1   -999  [band_1, coastal_aerosol]
#                     blue                1   -999             [band_2, blue]
#                     green               1   -999            [band_3, green]
#                     red                 1   -999              [band_4, red]
#                     nir                 1   -999              [band_5, nir]
#                     swir1               1   -999            [band_6, swir1]
#                     swir2               1   -999            [band_7, swir2]
# ls8_nbar_oli_albers coastal_aerosol     1   -999  [band_1, coastal_aerosol]
#                     blue                1   -999             [band_2, blue]
#                     green               1   -999            [band_3, green]
#                     red                 1   -999              [band_4, red]
#                     nir                 1   -999              [band_5, nir]
#                     swir1               1   -999            [band_6, swir1]
#                     swir2               1   -999            [band_7, swir2]

# %%
lat = (-41.68, -41.87)
long = (145.2, 145.5)


query_pre = {
        'lat': lat,
        'lon': long,
        #'crs': 'EPSG:3577',
        #'output_crs': 'EPSG:3577',
        'time': ('2018')
        }

ds = dc.load(product='ls8_nbart_tmad_annual',
                      group_by = 'solar_day', **query_pre)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, x: 1103, y: 927)
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01
#   * y        (y) float64 -4.615e+06 -4.615e+06 ... -4.638e+06 -4.638e+06
#   * x        (x) float64 1.122e+06 1.122e+06 1.122e+06 ... 1.149e+06 1.149e+06
# Data variables:
#     sdev     (time, y, x) float32 0.0005636803 0.0005892057 ... 0.0003885096
#     edev     (time, y, x) float32 0.016925894 0.01959325 ... 0.009622013
#     bcdev    (time, y, x) float32 0.03757719 0.03929099 ... 0.024180068
# Attributes:
#     crs:      EPSG:3577

# %%
ds.bcdev.plot(vmin=-1, vmax=1, cmap='RdYlGn')
